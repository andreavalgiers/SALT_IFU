# %%
import numpy as np
import astropy
import scipy
import matplotlib.pyplot as plt
import pyfits
import itertools
from astropy.stats import sigma_clip
import pylab as pl
import os
import matplotlib.animation as animation
import sys
from scipy import stats
from scipy import interpolate
from scipy.interpolate import UnivariateSpline
import math
import pandas

# %%
#### SALT TELESCOPE PARAMTERS

collFL = 647.09 # Collimator Focal Length [mm] 
camFL = 220.0 # Camera Focal Length [mm] 
platescale=18 # Platescale [micron pix^-1]
focalscale = 226.178 # focal scale [microns arcsecs^-1]
slitwidth= 0.9 # Slit Width [arcsec]
groove_sep=1./950. # Groove Separation [mm] 
primD=11 # Primary Mirror Diameter [m]
secD=2 #Secondary Mirror Diameter [m]
collectArea=91.89 #Collecting Area [m^2]
eff_RSS=0.2 # Efficiency of RSS instrument
eff_fib=0.78 # Efficiency of fiber
resem=4.233 # Resolution Element [pix]
totpix=2048 #Number of pixels in detector
slitpix=2031.84 #Number of pixels along slit length
pixArea=0.000324 # Area of Pixel mm^2
RN = 9 # Read Noise
npix = 17.92 # 
gain = 0.25 #
dark = 0.002 #

# %%
#### Calculation of Spectrograph

### Grating Equation= Central Wavelength
alpha=arange(20,55,5)
cent_wave=2*groove_sep*np.sin(alpha*np.pi/180.)*10**6 # [nm]

## Linear Dispersion
lin_disp=0.0861*np.cos(alpha*np.pi/180.) #[nm pix^-1]

## Fiber Size
fibersize=np.array([100.,150.,200.,300.,400.,500.,600.,800.])/focalscale # Diamter of fiber [arcsec]

# %%
### Sky Continuum
skywave = np.array([900, 950, 1000, 1050, 1100, 1150, 1200, 1250, 1300, 1350, 
   1400, 1450, 1500, 1550, 1600, 1650, 1700, 1750, 1800, 1850, 1900]);
skyflux = np.array([1.315709, 0.3790091, 1.11682, 1.045974, 0.9701224, 
   0.9064792, 0.9064792, 0.9064792, 0.9064792, 0.9064792, 0.9064792, 
   0.9064792, 0.9064792, 0.9064792, 0.9064792, 0.9064792, 0.9064792, 
   0.9064792, 0.9064792, 0.9064792, 0.9064792]);

## Interpolation of skywave and skyflux
f = interpolate.interp1d(skywave, skyflux,bounds_error=False, fill_value=1.315709)

### Sky Continuum At The Central Wavelengths
### What we actually measureed (after atmospheric tranparency and efficiency)

trans=np.array([0.948654,0.948654,0.99985,0.976124,0.356107,0.842272,0.982687]) # Atmospheric Transmission at Mauna Kea as a function
                                                                       # alpha
rss_eff=np.array([0.2,0.2,0.3,0.5,0.5,0.55,0.5]) # RSS efficiency at various alpha angles


skyflux_det=[]
for i in range(0,len(cent_wave)):
    
    skyflux_cent=f(cent_wave[i])*collectArea*np.pi*((fibersize/2)**2)*lin_disp[i]*trans[i]*rss_eff[i]*eff_fib # photons s^-1 pix
    skyflux_det.append(skyflux_cent)

skyflux_det=np.array(skyflux_det) # The detected sky intensity as a function of angle and fiber size
                                  # [photons s^-1 pix^1]

# %%
### Sky-Limited vs. Read-Noise
#### Sky-Limited: Sqrt(skyflux_det*exposure_time)
#### Read-Noise Limited: 3*RN



fib_sky_alpha= np.transpose(skyflux_det) # Gives the sky flux for each alpha for each fiber size

exp_time=[1.,60.,100.,300.,600.]
RN_lim=np.array( [3*RN]*(len(alpha)))

sky_lim=[]

for k in range(len(exp_time)):
    arr=[]
    for i in range(len(fib_sky_alpha)):
        arr.append(np.sqrt(fib_sky_alpha[i]*exp_time[k]))
        #arr.append(fib_sky_alpha[i]*exp_time[k])
    sky_lim.append(arr)

# %%
### The detected sky flux as a function of alpha for each fiber size. Units of photons/pix

## At exposure time t=1 sec
fib100_0=sky_lim[0][0]
fib150_0=sky_lim[0][1]
fib200_0=sky_lim[0][2]
fib300_0=sky_lim[0][3]
fib400_0=sky_lim[0][4]
fib500_0=sky_lim[0][5]
fib600_0=sky_lim[0][6]
fib800_0=sky_lim[0][7]

## At exposure time t=60 sec
fib100_1=sky_lim[1][0]
fib150_1=sky_lim[1][1]
fib200_1=sky_lim[1][2]
fib300_1=sky_lim[1][3]
fib400_1=sky_lim[1][4]
fib500_1=sky_lim[1][5]
fib600_1=sky_lim[1][6]
fib800_1=sky_lim[1][7]

## At exposure time t=300 sec
fib100_2=sky_lim[2][0]
fib150_2=sky_lim[2][1]
fib200_2=sky_lim[2][2]
fib300_2=sky_lim[2][3]
fib400_2=sky_lim[2][4]
fib500_2=sky_lim[2][5]
fib600_2=sky_lim[2][6]
fib800_2=sky_lim[2][7]

## At exposure time t=600 sec
fib100_3=sky_lim[3][0]
fib150_3=sky_lim[3][1]
fib200_3=sky_lim[3][2]
fib300_3=sky_lim[3][3]
fib400_3=sky_lim[3][4]
fib500_3=sky_lim[3][5]
fib600_3=sky_lim[3][6]
fib800_3=sky_lim[3][7]

# %%
plt.figure(figsize = (7,7))
plt.plot(alpha,RN_lim,'k-',label='3 x RN')
plt.plot(alpha,fib100_0,'r-',label='100 $\mu$m')
plt.plot(alpha,fib150_0,'b-',label='150 $\mu$m')
plt.plot(alpha,fib200_0,'m-',label='200 $\mu$m')
plt.plot(alpha,fib300_0,'g-',label='300 $\mu$m')
plt.plot(alpha,fib400_0,'y-',label='400 $\mu$m')
plt.plot(alpha,fib500_0,'r--',label='500 $\mu$m')
plt.plot(alpha,fib600_0,'b--',label='600 $\mu$m')
plt.plot(alpha,fib800_0,'m--',label='800 $\mu$m')
plt.title('Sky Limited vs. Detector Limited: t=1 s ')
plt.legend(loc='upper left',prop={'size':14},frameon=True)
plt.xlabel('$Grating\ Angle \ [deg]$')
plt.ylabel(r'$\sqrt{I_{sky}\ \epsilon \t}$   $[photons\ pix^1]$')
plt.show()

pandas.DataFrame([fib100_0-RN_lim,fib150_0-RN_lim,fib200_0-RN_lim,fib300_0-RN_lim,fib400_0-RN_lim,fib500_0-RN_lim,fib600_0-RN_lim,fib800_0-RN_lim],['100 $\mu$m','150 $\mu$m','200 $\mu$m','300 $\mu$m','400 $\mu$m','500 $\mu$m','600 $\mu$m','800 $\mu$m'],alpha).T
# Out:
#     100 $\mu$m  150 $\mu$m  200 $\mu$m  300 $\mu$m  400 $\mu$m  500 $\mu$m  \
# 20  -26.528568  -26.292852  -26.057135  -25.585703  -25.114271  -24.642839
# 25  -26.537018  -26.305527  -26.074036  -25.611053  -25.148071  -24.685089
# 30  -26.493591  -26.240387  -25.987183  -25.480774  -24.974366  -24.467957
# 35  -26.414029  -26.121043  -25.828058  -25.242086  -24.656115  -24.070144
# 40  -26.657738  -26.486607  -26.315476  -25.973214  -25.630952  -25.288690
# 45  -26.469596  -26.204394  -25.939193  -25.408789  -24.878385  -24.347982
# 50  -26.479186  -26.218779  -25.958371  -25.437557  -24.916743  -24.395929
#
#     600 $\mu$m  800 $\mu$m
# 20  -24.171406  -23.228542
# 25  -24.222107  -23.296143
# 30  -23.961549  -22.948732
# 35  -23.484173  -22.312230
# 40  -24.946428  -24.261904
# 45  -23.817578  -22.756771
# 50  -23.875114  -22.833486

# %%
plt.figure(figsize = (7,7))
plt.plot(alpha,RN_lim,'k-',label='3 x RN')
plt.plot(alpha,fib100_1,'r-',label='100 $\mu$m')
plt.plot(alpha,fib150_1,'b-',label='150 $\mu$m')
plt.plot(alpha,fib200_1,'m-',label='200 $\mu$m')
plt.plot(alpha,fib300_1,'g-',label='300 $\mu$m')
plt.plot(alpha,fib400_1,'y-',label='400 $\mu$m')
plt.plot(alpha,fib500_1,'r--',label='500 $\mu$m')
plt.plot(alpha,fib600_1,'b--',label='600 $\mu$m')
plt.plot(alpha,fib800_1,'m--',label='800 $\mu$m')
plt.title('Sky Limited vs. Detector Limited: t=60 s ')
plt.legend(loc='upper left',prop={'size':14},frameon=True)
plt.xlabel('$Grating\ Angle \ [deg]$')
plt.ylabel(r'$\sqrt{I_{sky}\ \epsilon \t}$   $[photons\ pix^1]$')
plt.show()

pandas.DataFrame([fib100_1-RN_lim,fib150_1-RN_lim,fib200_1-RN_lim,fib300_1-RN_lim,fib400_1-RN_lim,fib500_1-RN_lim,fib600_1-RN_lim,fib800_1-RN_lim],['100 $\mu$m','150 $\mu$m','200 $\mu$m','300 $\mu$m','400 $\mu$m','500 $\mu$m','600 $\mu$m','800 $\mu$m'],alpha).T
# Out:
#     100 $\mu$m  150 $\mu$m  200 $\mu$m  300 $\mu$m  400 $\mu$m  500 $\mu$m  \
# 20  -23.348301  -21.522452  -19.696602  -16.044903  -12.393204   -8.741506
# 25  -23.413755  -21.620633  -19.827511  -16.241266  -12.655022   -9.068777
# 30  -23.077376  -21.116064  -19.154753  -15.232129  -11.309505   -7.386882
# 35  -22.461087  -20.191630  -17.922173  -13.383260   -8.844347   -4.305433
# 40  -24.348850  -23.023274  -21.697699  -19.046549  -16.395398  -13.744248
# 45  -22.891511  -20.837266  -18.783021  -14.674532  -10.566043   -6.457554
# 50  -22.965790  -20.948685  -18.931580  -14.897370  -10.863161   -6.828951
#
#     600 $\mu$m  800 $\mu$m
# 20   -5.089807    2.213591
# 25   -5.482532    1.689957
# 30   -3.464258    4.380990
# 35    0.233480    9.311306
# 40  -11.093097   -5.790797
# 45   -2.349064    5.867914
# 50   -2.794741    5.273679

# %%
plt.figure(figsize = (7,7))
plt.plot(alpha,RN_lim,'k-',label='3 x RN')
plt.plot(alpha,fib100_2,'r-',label='100 $\mu$m')
plt.plot(alpha,fib150_2,'b-',label='150 $\mu$m')
plt.plot(alpha,fib200_2,'m-',label='200 $\mu$m')
plt.plot(alpha,fib300_2,'g-',label='300 $\mu$m')
plt.plot(alpha,fib400_2,'y-',label='400 $\mu$m')
plt.plot(alpha,fib500_2,'r--',label='500 $\mu$m')
plt.plot(alpha,fib600_2,'b--',label='600 $\mu$m')
plt.plot(alpha,fib800_2,'m--',label='800 $\mu$m')
plt.title('Sky Limited vs. Detector Limited: t=300 s ')
plt.legend(loc='upper left',prop={'size':14},frameon=True)
plt.xlabel('$Grating\ Angle \ [deg]$')
plt.ylabel(r'$\sqrt{I_{sky}\ \epsilon \t}$   $[photons\ pix^1]$')
plt.show()

pandas.DataFrame([fib100_2-RN_lim,fib150_2-RN_lim,fib200_2-RN_lim,fib300_2-RN_lim,fib400_2-RN_lim,fib500_2-RN_lim,fib600_2-RN_lim,fib800_2-RN_lim],['100 $\mu$m','150 $\mu$m','200 $\mu$m','300 $\mu$m','400 $\mu$m','500 $\mu$m','600 $\mu$m','800 $\mu$m'],alpha).T
# Out:
#     100 $\mu$m  150 $\mu$m  200 $\mu$m  300 $\mu$m  400 $\mu$m  500 $\mu$m  \
# 20  -22.285677  -19.928516  -17.571354  -12.857031   -8.142708   -3.428385
# 25  -22.370178  -20.055267  -17.740356  -13.110534   -8.480713   -3.850891
# 30  -21.935915  -19.403872  -16.871829  -11.807744   -6.743658   -1.679573
# 35  -21.140288  -18.210432  -15.280576   -9.420864   -3.561152    2.298559
# 40  -23.577380  -21.866069  -20.154759  -16.732139  -13.309518   -9.886898
# 45  -21.695963  -19.043945  -16.391926  -11.087889   -5.783853   -0.479816
# 50  -21.791857  -19.187786  -16.583715  -11.375572   -6.167430   -0.959287
#
#     600 $\mu$m  800 $\mu$m
# 20    1.285938   10.714584
# 25    0.778931   10.038575
# 30    3.384512   13.512683
# 35    8.158271   19.877695
# 40   -6.464277    0.380964
# 45    4.824221   15.432295
# 50    4.248855   14.665140

# %%
plt.figure(figsize = (7,7))
plt.plot(alpha,RN_lim,'k-',label='3 x RN')
plt.plot(alpha,fib100_3,'r-',label='100 $\mu$m')
plt.plot(alpha,fib150_3,'b-',label='150 $\mu$m')
plt.plot(alpha,fib200_3,'m-',label='200 $\mu$m')
plt.plot(alpha,fib300_3,'g-',label='300 $\mu$m')
plt.plot(alpha,fib400_3,'y-',label='400 $\mu$m')
plt.plot(alpha,fib500_3,'r--',label='500 $\mu$m')
plt.plot(alpha,fib600_3,'b--',label='600 $\mu$m')
plt.plot(alpha,fib800_3,'m--',label='800 $\mu$m')
plt.title('Sky Limited vs. Detector Limited: t=600 s ')
plt.legend(loc='upper left',prop={'size':14},frameon=True)
plt.xlabel('$Grating\ Angle \ [deg]$')
plt.ylabel(r'$\sqrt{I_{sky}\ \epsilon \t}$   $[photons\ pix^1]$')
plt.show()

pandas.DataFrame([fib100_3-RN_lim,fib150_3-RN_lim,fib200_3-RN_lim,fib300_3-RN_lim,fib400_3-RN_lim,fib500_3-RN_lim,fib600_3-RN_lim,fib800_3-RN_lim],['100 $\mu$m','150 $\mu$m','200 $\mu$m','300 $\mu$m','400 $\mu$m','500 $\mu$m','600 $\mu$m','800 $\mu$m'],alpha).T
# Out:
#     100 $\mu$m  150 $\mu$m  200 $\mu$m  300 $\mu$m  400 $\mu$m  500 $\mu$m  \
# 20  -18.834553  -14.751830  -10.669106   -2.503659    5.661788   13.827235
# 25  -18.980913  -14.971370  -10.961827   -2.942740    5.076347   13.095433
# 30  -18.228747  -13.843120   -9.457494   -0.686240    8.085013   16.856266
# 35  -16.850681  -11.776022   -6.701363    3.447956   13.597275   23.746594
# 40  -21.071847  -18.107771  -15.143695   -9.215542   -3.287390    2.640763
# 45  -17.813139  -13.219708   -8.626277    0.560584    9.747445   18.934307
# 50  -17.979233  -13.468849   -8.958465    0.062302    9.083070   18.103837
#
#     600 $\mu$m  800 $\mu$m
# 20   21.992682   38.323576
# 25   21.114520   37.152694
# 30   25.627519   43.170026
# 35   33.895912   54.194550
# 40    8.568916   20.425221
# 45   28.121168   46.494891
# 50   27.124605   45.166140
